# %% [markdown]
# This Applicaiton is for understanding Exception Handling

# %%
numvalue = input("Enter a number")
num1 = int(numvalue)
num2 = int(input("Enter another number"))

result = num1/num2
print("The result of the division is:", result)
# Out:
# The result of the division is: 2.0

# %%
try:
    num1 = int(input("Enter a number: "))
    num2 = int(input("Enter another number: "))
    result = num1 / num2
    print("The result of the division is:", result)
except ValueError:
    print("Invalid input. Please enter valid integers.")
except ZeroDivisionError:
    print("Error: Division by zero is not allowed.")
# Out:
# Invalid input. Please enter valid integers.

# %%
try:
    num1 = int(input("Enter a number: "))
    num2 = int(input("Enter another number: "))
    try:
        result = num1 / num2
        print("The result of the division is:", result)
    except ZeroDivisionError:
        print("Error: Division by zero is not allowed.")
except ValueError:
    print("Invalid input. Please enter valid integers.")
# Out:
# Error: Division by zero is not allowed.

# %%
try:
    num1 = int(input("Enter a number: "))
    num2 = int(input("Enter another number: "))
    try:
        result = num1 / num2
        print("The result of the division is:", result)
    except ZeroDivisionError:
        print("Error: Division by zero is not allowed.")
    finally:
        print("Execution completed for the division operation.") # close resources, cleanup, etc.
except ValueError:
    print("Invalid input. Please enter valid integers.")
finally:
    print("Execution completed for number verification.")#close resources, cleanup, etc.
print("This is the end of the program.")
# Out:
# The result of the division is: 2.0
# Execution completed for the division operation.
# Execution completed for number verification.
# This is the end of the program.
