# %% [markdown]
# This application code is meant for accepting user inputs

# %%
name = input("Enter user name")
age = input("Enter user age")
gender = input("Enter user gender")

# %%
print("Mentioned name is: " + name)
print("Mentioned age is: " + age)
print("Mentioned gender is: " + gender)
# Out:
# Mentioned name is: Mahesh
# Mentioned age is: 25
# Mentioned gender is: Male
