# %%
import numpy as np
import pandas as pd

from sklearn.preprocessing import OneHotEncoder, LabelEncoder
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.impute import SimpleImputer

# df = pd.read_csv('house-clean.csv')
df = pd.read_csv("healthcare_dataset.csv")

#Use Label encoder for Neighborhood
lencneigh = LabelEncoder()
# df["Neighborhood"] = lencneigh.fit_transform(df["Neighborhood"])

#Use Label encoder for Bloodgroup
df["Blood Type"] = lencneigh.fit_transform(df["Blood Type"])
# df["Medical Condition"] = lencneigh.fit_transform(df["Medical Condition"])
df["Insurance Provider"] = lencneigh.fit_transform(df["Insurance Provider"])
df["Medication"] = lencneigh.fit_transform(df["Medication"])
df["Test Results"] = lencneigh.fit_transform(df["Test Results"])
df["Admission Type"] = lencneigh.fit_transform(df["Admission Type"])

onehotenc = OneHotEncoder(sparse_output=False)
# # df["Pool"] = onehotenc.fit_transform(df[["Pool"]]).toarray()
# df["Pool"] = onehotenc.fit_transform(df[["Pool"]])
df["Gender"] = onehotenc.fit_transform(df[["Gender"]])
df["Medical Condition"] = onehotenc.fit_transform(df[["Medical Condition"]])
df
# Out:
#                     Name  Age  Gender  Blood Type  Medical Condition  \
# 0          Bobby JacksOn   30     0.0           5                0.0
# 1           LesLie TErRy   62     0.0           0                0.0
# 2            DaNnY sMitH   76     1.0           1                0.0
# 3           andrEw waTtS   28     1.0           6                0.0
# 4          adrIENNE bEll   43     1.0           2                0.0
# ...                  ...  ...     ...         ...                ...
# 55495  eLIZABeTH jaCkSOn   42     1.0           6                0.0
# 55496         KYle pEREz   61     1.0           3                0.0
# 55497       HEATher WaNG   38     1.0           4                0.0
# 55498     JENniFER JOneS   43     0.0           7                1.0
# 55499       jAMES GARCiA   53     1.0           6                1.0
#
#       Date of Admission            Doctor                      Hospital  \
# ...

# %%
import numpy as np
import pandas as pd

from sklearn.preprocessing import OneHotEncoder, LabelEncoder
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.impute import SimpleImputer

scaler = StandardScaler()
scaler.fit_transform(df[["Age","Gender","Blood Type","Medication"]])
# Out:
# array([[-1.09882435, -0.99913551,  0.65834792,  0.70897543],
#        [ 0.53363905, -0.99913551, -1.52536431, -0.70622153],
#        [ 1.24784178,  1.00086524, -1.08862186, -1.41382001],
#        ...,
#        [-0.6907085 ,  1.00086524,  0.22160548, -0.70622153],
#        [-0.43563609, -0.99913551,  1.53183282, -0.70622153],
#        [ 0.07450872,  1.00086524,  1.09509037, -0.70622153]],
#       shape=(55500, 4))
