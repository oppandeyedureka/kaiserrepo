# %%
import pandas as pd
import numpy as np

hpd = pd.read_csv('D:\P01_Learning Services\Prudentia\Session Materials\Datasets\houseprice-dirty.csv', index_col=0)
#hpd.head()
hpd.info()
#hpd.describe()
#print("Shape : ",hpd.shape)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1460 entries, 1 to 1460
# Data columns (total 80 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   MSSubClass     1460 non-null   int64
#  1   MSZoning       1460 non-null   object
#  2   LotFrontage    1201 non-null   float64
#  3   LotArea        1460 non-null   int64
#  4   Street         1460 non-null   object
#  5   Alley          91 non-null     object
#  6   LotShape       1460 non-null   object
#  7   LandContour    1460 non-null   object
#  8   Utilities      1460 non-null   object
#  9   LotConfig      1460 non-null   object
#  10  LandSlope      1460 non-null   object
#  11  Neighborhood   1460 non-null   object
#  12  Condition1     1460 non-null   object
#  13  Condition2     1460 non-null   object
#  14  BldgType       1460 non-null   object
#  15  HouseStyle     1460 non-null   object
#  16  OverallQual    1460 non-null   int64
# ...

# %%
#Rows to be droppped
hpd.duplicated().count()
hpd.drop_duplicates(inplace=True)

#Columns to be dropped
# Columns to be dropped (drop only those that actually exist in the dataframe)
columns_to_drop = [col for col in ['BldgType',	'HouseStyle','LandSlope','LotConfig','MSSubClass', 'MSZoning', 'LotFrontage', 'Street', 'Alley', 'LotShape', 'LandContour', 'Utilities', 'Condition1', 'Condition2'] if col in hpd.columns]
hpd.drop(columns=columns_to_drop, inplace=True)

print("Shape after dropping columns:", hpd.shape)
hpd.info()

#hpd.isna().sum()
# Out:
# Shape after dropping columns: (1460, 62)
# <class 'pandas.core.frame.DataFrame'>
# Index: 1460 entries, 1 to 1460
# Data columns (total 62 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   LotArea        1460 non-null   int64
#  1   Neighborhood   1460 non-null   object
#  2   OverallQual    1460 non-null   int64
#  3   OverallCond    1460 non-null   int64
#  4   YearBuilt      1460 non-null   int64
#  5   YearRemodAdd   1460 non-null   int64
#  6   RoofStyle      1460 non-null   object
#  7   RoofMatl       1460 non-null   object
#  8   Exterior1st    1460 non-null   object
#  9   Exterior2nd    1460 non-null   object
#  10  MasVnrType     588 non-null    object
#  11  MasVnrArea     1452 non-null   float64
#  12  ExterQual      1460 non-null   object
#  13  ExterCond      1460 non-null   object
#  14  Foundation     1460 non-null   object
#  15  BsmtQual       1423 non-null   object
#  16  BsmtCond       1423 non-null   object
# ...

# %%
Id	LotFrontage	LotArea	OverallQual	YearBuilt	TotalBsmtSF	GrLivArea	BedroomAbvGr	GarageArea	SalePrice
hpd
