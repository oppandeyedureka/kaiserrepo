# %% [markdown]
# Use various Descriptive resources

# %%
#Calulating Mean values
sum = 12 + 15 + 10 + 18 + 15
count = 5
meanvalue = sum/count
print(meanvalue)
# Out:
# 14.0

# %%
#median value
values = 120, 150, 155, 160, 300

# %%
from math import math
#variance calculation
sum = 360000 + 160000 + 2560000 + 1960000 +160000
count = 5
variance = sum/(count-1)
print(variance)

stddev = sqrt(variance)
# Out:
# 1300000.0
