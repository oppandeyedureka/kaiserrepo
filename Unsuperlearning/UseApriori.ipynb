# %%
# !pip install mlxtend
# Out:
# Collecting mlxtend
#   Downloading mlxtend-0.24.0-py3-none-any.whl.metadata (7.3 kB)
# INFO: pip is looking at multiple versions of mlxtend to determine which version is compatible with other requirements. This could take a while.
#   Downloading mlxtend-0.23.4-py3-none-any.whl.metadata (7.3 kB)
# Requirement already satisfied: scipy>=1.2.1 in c:\users\hait\appdata\local\programs\python\python310\lib\site-packages (from mlxtend) (1.15.3)
# Requirement already satisfied: numpy>=1.16.2 in c:\users\hait\appdata\local\programs\python\python310\lib\site-packages (from mlxtend) (2.2.6)
# Requirement already satisfied: pandas>=0.24.2 in c:\users\hait\appdata\local\programs\python\python310\lib\site-packages (from mlxtend) (2.3.3)
# Requirement already satisfied: scikit-learn>=1.3.1 in c:\users\hait\appdata\local\programs\python\python310\lib\site-packages (from mlxtend) (1.7.2)
# Requirement already satisfied: matplotlib>=3.0.0 in c:\users\hait\appdata\local\programs\python\python310\lib\site-packages (from mlxtend) (3.10.8)
# Requirement already satisfied: joblib>=0.13.2 in c:\users\hait\appdata\local\programs\python\python310\lib\site-packages (from mlxtend) (1.5.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\hait\appdata\local\programs\python\python310\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\hait\appdata\local\programs\python\python310\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\hait\appdata\local\programs\python\python310\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\hait\appdata\local\programs\python\python310\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\hait\appdata\roaming\python\python310\site-packages (from matplotlib>=3.0.0->mlxtend) (26.0)
# Requirement already satisfied: pillow>=8 in c:\users\hait\appdata\local\programs\python\python310\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (12.2.0)
# Requirement already satisfied: pyparsing>=3 in c:\users\hait\appdata\local\programs\python\python310\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\hait\appdata\roaming\python\python310\site-packages (from matplotlib>=3.0.0->mlxtend) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\hait\appdata\local\programs\python\python310\lib\site-packages (from pandas>=0.24.2->mlxtend) (2026.1.post1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\hait\appdata\local\programs\python\python310\lib\site-packages (from pandas>=0.24.2->mlxtend) (2026.1)
# Requirement already satisfied: six>=1.5 in c:\users\hait\appdata\roaming\python\python310\site-packages (from python-dateutil>=2.7->matplotlib>=3.0.0->mlxtend) (1.17.0)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\hait\appdata\local\programs\python\python310\lib\site-packages (from scikit-learn>=1.3.1->mlxtend) (3.6.0)
# Downloading mlxtend-0.23.4-py3-none-any.whl (1.4 MB)
#    ---------------------------------------- 0.0/1.4 MB ? eta -:--:--
#    ---------------------------------------- 1.4/1.4 MB 7.0 MB/s  0:00:00
# Installing collected packages: mlxtend
# Successfully installed mlxtend-0.23.4
# [notice] A new release of pip is available: 26.1 -> 26.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
### Use Case: Market Basket Analysis
import pandas as pd
from mlxtend.frequent_patterns import apriori, association_rules
from sklearn.preprocessing import StandardScaler

# Sample transactional dataset
data = {
     'Milk': [1, 0, 1, 1, 0],
     'Bread': [1, 1, 0, 1, 1],
     'Butter': [0, 1, 1, 1, 0],
     'Cheese': [1, 1, 0, 1, 1],
     'Eggs': [0, 0, 1, 1, 1]
 }
df = pd.DataFrame(data)

# df = pd.read_csv('Mall_Customers.csv')

# df.head()

# X = df[["Annual Income (k$)", "Spending Score (1-100)"]]

# # Standardize features
# scaler = StandardScaler()
# X_scaled = scaler.fit_transform(X)


# Step 1: Generate Frequent Itemsets
frequent_itemsets = apriori(df, min_support=0.6, use_colnames=True)
# frequent_itemsets = apriori(X_scaled)

# Step 2: Generate Association Rules
rules = association_rules(frequent_itemsets, metric="confidence", min_threshold=0.7)

# Display the frequent itemsets and rules
print("Frequent Itemsets:\n", frequent_itemsets)
print("\nAssociation Rules:\n", rules)
# Out:
# Frequent Itemsets:
#     support         itemsets
# 0      0.6           (Milk)
# 1      0.8          (Bread)
# 2      0.6         (Butter)
# 3      0.8         (Cheese)
# 4      0.6           (Eggs)
# 5      0.8  (Bread, Cheese)
#
# Association Rules:
#    antecedents consequents  antecedent support  ...  jaccard  certainty  kulczynski
# 0     (Bread)    (Cheese)                 0.8  ...      1.0        1.0         1.0
# 1    (Cheese)     (Bread)                 0.8  ...      1.0        1.0         1.0
#
# [2 rows x 14 columns]
