# %%
file = open("file2.txt","w")
file.writelines("Welcome to Python File handling.hello")
file.close()

# %%
file2 = open("file2.txt","r+")
print(file2.readlines())
file2.close()
# Out:
# ['Welcome to Python File handling.hello']

# %%
import csv
with open("file1.csv",mode="r") as file:
    csvfile = csv.reader(file)
    next(csvfile)
    for line in csvfile:
        print(line)
# Out:
# ['Ganesh', '24', 'Mumbai']
# ['Mahesh', '28', 'Pune']
