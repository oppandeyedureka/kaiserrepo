# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

tdf = pd.read_csv("titanic-dataset.csv")
sns.histplot(data=tdf, x="Age", hue="Sex", multiple="stack", palette="pastel")
#plt.show()
# Out:
# <Axes: xlabel='Age', ylabel='Count'>

# %%
import seaborn as sns
import matplotlib as mt
import pandas as pd

tdf = pd.read_excel("Product-Sales-Region.xlsx")
sns.boxplot(x="StoreLocation", y="TotalPrice", data=tdf, palette="pastel", hue="StoreLocation")
mt.pyplot.show()

# %%
import seaborn as sns
import matplotlib as mt
import pandas as pd

tdf = pd.read_excel("Product-Sales-Region.xlsx")
#sns.barplot(x="Salesperson", y="TotalPrice", data=tdf, palette="pastel", hue="Salesperson")
sns.countplot(x="Salesperson", data=tdf, palette="pastel", hue="Salesperson")
mt.pyplot.show()

# %%
import seaborn as sns
import matplotlib as mt
import pandas as pd

tdf = pd.read_csv("house-clean.csv")
sns.scatterplot(x="Price", y="SqFt", data=tdf, hue="Bedrooms", palette="pastel")
mt.pyplot.show()

# %%
import seaborn as sns
import matplotlib as mt
import pandas as pd

# tdf = pd.read_csv("house-clean.csv")
# cols = ['Price', 'SqFt', 'Bedrooms', 'Bathrooms']
# sns.heatmap(tdf[cols].corr(), annot=True, cmap='coolwarm', center=0)

tdf = pd.read_csv("Titanic-Dataset.csv")
cols = ['Survived', 'Fare', 'Age', 'SibSp', 'Parch']
sns.heatmap(tdf[cols].corr(), annot=True, cmap='coolwarm', center=0)
mt.pyplot.show()

# %%
import seaborn as sns
import matplotlib as mt
import pandas as pd

tdf = pd.read_csv("houseprice-dirty.csv")
#cols = ['SalePrice', 'Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd', 'MasVnrArea', 'BsmtFinSF1', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', '1stFlrSF', '2ndFlrSF', 'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath', 'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'TotRmsAbvGrd', 'Fireplaces', 'GarageYrBlt', 'GarageCars', 'GarageArea']
#cols = ['SalePrice', 'Id', 'MSSubClass', 'LotFrontage', 'LotArea', 'OverallQual', 'OverallCond']
#cols = ['SalePrice', 'YearBuilt', 'YearRemodAdd', 'MasVnrArea', 'BsmtFinSF1', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF']
cols = ['SalePrice','1stFlrSF', '2ndFlrSF', 'LowQualFinSF', 'GrLivArea', 'BsmtFullBath']
sns.heatmap(tdf[cols].corr(), annot=True, cmap='coolwarm', center=0)
# Out:
# <Axes: >

# %%
import seaborn as sns
sns.set_theme(style="whitegrid")

diamonds = sns.load_dataset("diamonds")
clarity_ranking = ["I1", "SI2", "SI1", "VS2", "VS1", "VVS2", "VVS1", "IF"]

sns.boxenplot(
    diamonds, x="clarity", y="carat",
    color="b", order=clarity_ranking, width_method="linear",
)
# Out:
# <Axes: xlabel='clarity', ylabel='carat'>

# %%
import pandas as pd
import seaborn as sns
sns.set_theme()

# Load the brain networks example dataset
df = sns.load_dataset("brain_networks", header=[0, 1, 2], index_col=0)

# Select a subset of the networks
used_networks = [1, 5, 6, 7, 8, 12, 13, 17]
used_columns = (df.columns.get_level_values("network")
                          .astype(int)
                          .isin(used_networks))
df = df.loc[:, used_columns]

# Create a categorical palette to identify the networks
network_pal = sns.husl_palette(8, s=.45)
network_lut = dict(zip(map(str, used_networks), network_pal))

# Convert the palette to vectors that will be drawn on the side of the matrix
networks = df.columns.get_level_values("network")
network_colors = pd.Series(networks, index=df.columns).map(network_lut)

# Draw the full plot
g = sns.clustermap(df.corr(), center=0, cmap="vlag",
                   row_colors=network_colors, col_colors=network_colors,
                   dendrogram_ratio=(.1, .2),
                   cbar_pos=(.02, .32, .03, .2),
                   linewidths=.75, figsize=(12, 13))

g.ax_row_dendrogram.remove()

# %%
import seaborn as sns
sns.set_theme(style="ticks")

tdf = pd.read_excel("Product-Sales-Region.xlsx")
df = sns.load_dataset("penguins")
#df.describe()
#df.info()

#df = tdf[['Salesperson','PaymentMethod','Product','RegionManager']]
df1 = tdf[['Quantity','Discount','TotalPrice','RegionManager']]
sns.pairplot(df1, hue="RegionManager")
#sns.pairplot(df, hue="species")
#plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
sns.set_theme(style="dark")

# Load the example tips dataset
tips = sns.load_dataset("tips")
#tips.describe()
#tips.info()
#tips.head()

# Draw a nested violinplot and split the violins for easier comparison
# sns.violinplot(data=tips, x="day", y="total_bill", hue="smoker",
#                 split=True, inner="quart", fill=False,
#                 palette={"Yes": "g", "No": ".35"})

#tdf = pd.read_excel("Product-Sales-Region.xlsx")
#sns.violinplot(data=tdf, x="StoreLocation", y="TotalPrice", inner="quart", hue="RegionManager", palette="pastel")

hdf = pd.read_csv("healthcare_dataset.csv")
sns.violinplot(data=hdf, x="Medical Condition", y="Age",  hue="Test Results", palette="pastel")
# Out:
# <Axes: xlabel='Medical Condition', ylabel='Age'>

# %%
import numpy as np
import seaborn as sns
sns.set_theme(style="ticks")

# rs = np.random.RandomState(11)
# x = rs.gamma(2, size=1000)
# y = -.5 * x + rs.normal(size=1000)

# sns.jointplot(x=x, y=y, kind="hex", color="#4CB391")

hdf = pd.read_csv("house-clean.csv")
sns.jointplot(x=hdf["SqFt"], y=hdf["Price"], kind="hex", color="#4CB391")
