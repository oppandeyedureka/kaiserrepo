# %%
import pandas as pd
import seaborn as sns

taxis_df = pd.read_csv("taxidata.csv")
#print(taxis_df.info())

taxis_df = pd.to_datetime(taxis_df['pickup_datetime'])
print(taxis_df.info())

# Set 'pickup' column as the datetime index
taxis_df.set_index('pickup_datetime', inplace=True)
 
# print the newly set index
#print(taxis_df.index[:5])
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 200000 entries, 0 to 199999
# Series name: pickup_datetime
# Non-Null Count   Dtype
# --------------   -----
# 200000 non-null  datetime64[ns]
# dtypes: datetime64[ns](1)
# memory usage: 1.5 MB
# None
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_22852\1635991257.py in ?()
#       7 taxis_df = pd.to_datetime(taxis_df['pickup_datetime'])
#       8 print(taxis_df.info())
#       9
#      10 # Set 'pickup' column as the datetime index
# ---> 11 taxis_df.set_index('pickup_datetime', inplace=True)
#      12
#      13 # print the newly set index
#      14 #print(taxis_df.index[:5])
#
# c:\Users\Hait\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6317             and name not in self._accessors
# ...

# %%
# Extract date and time components
taxis_df.dtype
# Out:
# dtype('<M8[ns]')
