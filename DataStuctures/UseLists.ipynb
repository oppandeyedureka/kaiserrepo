# %%
#Empty List
mylistobj = []
print(len(mylistobj))

mylistobj2 = [10,"Hello",2223899]
print(mylistobj2)

print(mylistobj2[0], mylistobj2[1], mylistobj2[2])#Access via index
print(mylistobj2[-1])

mylistobj2.append(1231.4435)
print("After Append", mylistobj2)

mylistobj2.insert(4, "Perks")
print("After Insert", mylistobj2)

mylistobj2[2] = "Welcome"
print(mylistobj2)
mylistobj2.remove("Perks")
print(mylistobj2)

colorslist = ["Red","Green","Blue"]
print(colorslist)
colorslist.sort()
print(colorslist)
print(colorslist.count("Blue"))

emplist = ["Ganesh","Mahesh","Dinesh", "Suresh"]
for emp in emplist:
    print(emp)

print(emplist[1:len(emplist)])
# Out:
# 0
# [10, 'Hello', 2223899]
# 10 Hello 2223899
# 2223899
# After Append [10, 'Hello', 2223899, 1231.4435]
# After Insert [10, 'Hello', 2223899, 1231.4435, 'Perks']
# [10, 'Hello', 'Welcome', 1231.4435, 'Perks']
# [10, 'Hello', 'Welcome', 1231.4435]
# ['Red', 'Green', 'Blue']
# ['Blue', 'Green', 'Red']
# 1
# Ganesh
# Mahesh
# Dinesh
# Suresh
# ['Mahesh', 'Dinesh', 'Suresh']

# %%
stringvalues = "Hello, welcome, hi"
valuelist = stringvalues.split(", ")
print(len(valuelist))
# Out:
# 3

# %%
complexlist = [[1,2],[3,4]] #2x2
complexlist2 = [[1,2,3],[4,5.6],[7,8,9]] #3x3

for i in complexlist:
    for j in complexlist[i]:
        print(complexlist[i][j])

# %%
numbers = [1, 2, 3, 4, 5]

# The shorthand way to create a new list
squared_numbers = [x * x for x in numbers]

print(f"Squared List: {squared_numbers}")
