# %%
num1 = 45
num2 = 5
print(num1 == num2)
# Out:
# False

# %%
num1 = 45
num2 = 5
print(num1 > num2)
# Out:
# True

# %%
num1 = 45
num2 = 5
print(num1 < num2)
# Out:
# False

# %%
num1 = 45
num2 = 5
print(num1 >= num2)
# Out:
# True

# %%
num1 = 45
num2 = 5
print(num1 != num2)
# Out:
# True

# %%
num1 = 45
num2 = 5
num3 = num1
print(num1 is num3)
# Out:
# True
