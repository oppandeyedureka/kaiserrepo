# %%
str1 = "Hello"
str2 = "World"
print(str1 + " " + str2)

print(str1 * 3)
# Out:
# Hello World
# HelloHelloHello

# %%
boolvalue01 = True
boolvalue02 = True

print(boolvalue01 and boolvalue02)
# Out:
# True

# %%
boolvalue01 = True
boolvalue02 = False

print(boolvalue01 or boolvalue02)
# Out:
# True

# %%
boolvalue01 = True
boolvalue02 = True

print(not boolvalue01)
# Out:
# False
