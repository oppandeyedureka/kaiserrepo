# %%
24 + 25
# Out:
# 49

# %%
num1 = 24
num2 = 25
print(num1 + num2)
# Out:
# 49

# %%
num1 = 24
num2 = 25
print(num1 - num2)
# Out:
# -1

# %%
num1 = 24
num2 = 25
print(num1 * num2)
# Out:
# 600

# %%
num1 = 24
num2 = 25
print(num1 / num2)
# Out:
# 0.96

# %%
num1 = 24
num2 = 25
print(num1 % num2)
# Out:
# 24

# %%
num1 = 24
num2 = 25
print(num1 // num2)
# Out:
# 0

# %%
(12+34) * 2 / 10
# Out:
# 9.2

# %%
2**4
# Out:
# 16
